# %% [markdown]
# # Engineered Data Quality Report

# %% [markdown]
# In this notebook we are going to create a data quality report piece-by-piece and then put it all together at the end.

# %%
# Import the libraries we need
import pandas as pd
import pyreadr

# %%
# Import the data from the source CSV file the 'Create a Pandas DataFrame From a CSV File' recipe and take a peek
credit_card_default_raw = pd.read_csv('./Data/credit_card_default.csv')
result = pyreadr.read_r('./Data/credit_card_default_eng.RData') 
credit_card_default_eng = result[None]
credit_card_default = credit_card_default_eng.copy()
df_flags = credit_card_default_raw['data.group']
credit_card_default = credit_card_default.join(df_flags)

credit_card_default.head()
# Out:
#    DEFAULT age_bins      bill_avg  payment_avg  pay_ratio1  pay_ratio2  \
# 0        1    21-30   1284.000000   114.833333    0.000000    1.000000
# 1        1    21-30   2846.166667   833.333333    0.000000    0.372856
# 2        0    31-40  16942.166667  1836.333333    0.108220    0.110628
# 3        0    31-40  38555.666667  1398.000000    0.041465    0.040961
# 4        0    51-60  18223.166667  9841.500000    0.352734    1.023608
#
#    pay_ratio3  pay_ratio4  pay_ratio5  ratio_avg  ...     util3     util4  \
# 0    1.000000    1.000000    1.000000   0.800000  ...  0.034450  0.000000
# 1    0.305623    0.289436    0.000000   0.193583  ...  0.022350  0.027267
# 2    0.069779    0.066899    0.064313   0.083968  ...  0.150656  0.159233
# 3    0.042382    0.037985    0.036180   0.039794  ...  0.985820  0.566280
# 4    0.477555    0.470072    0.036015   0.471997  ...  0.716700  0.418800
#
#       util5     util6  util_avg  balance_growth_6mo  bill_max  payment_max  \
# 0  0.000000  0.000000  0.064200           -0.195650      3913          689
# 1  0.028792  0.028792  0.023987            0.006442      3455         2000
# 2  0.166089  0.166089  0.187133           -0.158789     29239         5000
# 3  0.579180  0.579180  0.769153           -0.360620     49291         2019
# 4  0.382920  0.382920  0.364513            0.210580     35835        36681
#
#    pay_max  data.group
# 0      2.0           1
# 1      2.0           3
# 2      0.0           1
# 3      0.0           3
# 4      0.0           3
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Available Columns

# %%
# Create a DataFrame of the columns in the credit_card_default dataframe
columns = pd.DataFrame(list(credit_card_default.columns.values))
columns
# Out:
#                      0
# 0              DEFAULT
# 1             age_bins
# 2             bill_avg
# 3          payment_avg
# 4           pay_ratio1
# 5           pay_ratio2
# 6           pay_ratio3
# 7           pay_ratio4
# 8           pay_ratio5
# 9            ratio_avg
# 10               util1
# 11               util2
# 12               util3
# 13               util4
# 14               util5
# 15               util6
# 16            util_avg
# 17  balance_growth_6mo
# 18            bill_max
# 19         payment_max
# 20             pay_max
# 21          data.group

# %% [markdown]
# ## Data Types

# %%
# Create a DataFrame of the data type of each column
data_types = pd.DataFrame(credit_card_default.dtypes,
                          columns=['Data Type'])
data_types
# Out:
#                    Data Type
# DEFAULT                int32
# age_bins            category
# bill_avg             float64
# payment_avg          float64
# pay_ratio1           float64
# pay_ratio2           float64
# pay_ratio3           float64
# pay_ratio4           float64
# pay_ratio5           float64
# ratio_avg            float64
# util1                float64
# util2                float64
# util3                float64
# util4                float64
# util5                float64
# util6                float64
# util_avg             float64
# balance_growth_6mo   float64
# bill_max               int32
# payment_max            int32
# pay_max              float64
# data.group             int64

# %% [markdown]
# ## Count of Missing Values in Each Column

# %%
# Create a DataFrame with the count of missing values in each column
missing_data_counts = pd.DataFrame(credit_card_default.isnull().sum(),
                                   columns=['Missing Values'])
missing_data_counts
# Out:
#                     Missing Values
# DEFAULT                          0
# age_bins                         0
# bill_avg                         0
# payment_avg                      0
# pay_ratio1                       0
# pay_ratio2                       0
# pay_ratio3                       0
# pay_ratio4                       0
# pay_ratio5                       0
# ratio_avg                        0
# util1                            0
# util2                            0
# util3                            0
# util4                            0
# util5                            0
# util6                            0
# util_avg                         0
# balance_growth_6mo               0
# bill_max                         0
# payment_max                      0
# pay_max                          0
# data.group                       0

# %% [markdown]
# ## Count of Present Values in Each Column

# %%
# Create a DataFrame with the count of present values in each column
present_data_counts = pd.DataFrame(credit_card_default.count(),
                                   columns=['Present Values'])
present_data_counts
# Out:
#                     Present Values
# DEFAULT                      30000
# age_bins                     30000
# bill_avg                     30000
# payment_avg                  30000
# pay_ratio1                   30000
# pay_ratio2                   30000
# pay_ratio3                   30000
# pay_ratio4                   30000
# pay_ratio5                   30000
# ratio_avg                    30000
# util1                        30000
# util2                        30000
# util3                        30000
# util4                        30000
# util5                        30000
# util6                        30000
# util_avg                     30000
# balance_growth_6mo           30000
# bill_max                     30000
# payment_max                  30000
# pay_max                      30000
# data.group                   30000

# %% [markdown]
# ## Number of Unique Values Per-Column

# %%
# Create DataFrame with the count of unique values in each column
unique_value_counts = pd.DataFrame(columns=['Unique Values'])
for v in list(credit_card_default.columns.values):
    unique_value_counts.loc[v] = [credit_card_default[v].nunique()]
unique_value_counts
# Out:
#                     Unique Values
# DEFAULT                         2
# age_bins                        6
# bill_avg                    27370
# payment_avg                 19180
# pay_ratio1                  20209
# pay_ratio2                  20042
# pay_ratio3                  19411
# pay_ratio4                  18580
# pay_ratio5                  18025
# ratio_avg                   24820
# util1                       25565
# util2                       25088
# util3                       24738
# util4                       24452
# util5                       24075
# util6                       24075
# util_avg                    28402
# balance_growth_6mo          27137
# bill_max                    23979
# payment_max                 11670
# pay_max                         9
# data.group                      3

# %% [markdown]
# ## The Minimum Value In Each Column

# %%
credit_card_default.age_bins = credit_card_default.age_bins.values.as_ordered() # need to convert

# %%
# Create a DataFrame with the minimum value in each column
minimum_values = pd.DataFrame(columns=['Minimum Value'])
for v in list(credit_card_default.columns.values):
    minimum_values.loc[v] = [credit_card_default[v].min()]
minimum_values
# Out:
#                    Minimum Value
# DEFAULT                        0
# age_bins                   21-30
# bill_avg           -56043.166667
# payment_avg                  0.0
# pay_ratio1                   0.0
# pay_ratio2                   0.0
# pay_ratio3                   0.0
# pay_ratio4                   0.0
# pay_ratio5                   0.0
# ratio_avg                    0.0
# util1                  -0.619892
# util2                   -1.39554
# util3                    -1.0251
# util4                    -1.3745
# util5                  -0.876743
# util6                  -0.876743
# util_avg                -0.23259
# balance_growth_6mo       -4.7004
# bill_max                   -6029
# payment_max                    0
# pay_max                      0.0
# data.group                     1

# %% [markdown]
# ## The Maximum Value In Each Column

# %%
# Create a DataFrame with the minimum value in each column
maximum_values = pd.DataFrame(columns=['Maximum Value'])
for v in list(credit_card_default.columns.values):
    maximum_values.loc[v] = [credit_card_default[v].max()]
maximum_values
# Out:
#                     Maximum Value
# DEFAULT                         1
# age_bins                    71-80
# bill_avg            877313.833333
# payment_avg         627344.333333
# pay_ratio1            4444.333333
# pay_ratio2                 5001.0
# pay_ratio3            4444.333333
# pay_ratio4             129.705128
# pay_ratio5             690.655172
# ratio_avg             2667.199955
# util1                      6.4553
# util2                      6.3805
# util3                   10.688575
# util4                     5.14685
# util5                      4.9355
# util6                      4.9355
# util_avg                 5.537758
# balance_growth_6mo         1.7911
# bill_max                  1664089
# payment_max               1684259
# pay_max                       8.0
# data.group                      3

# %% [markdown]
# # Bring It All Together

# %%
# Merge all the DataFrames together by the index
data_quality_report = data_types.join(present_data_counts).join(missing_data_counts).join(unique_value_counts).join(minimum_values).join(maximum_values)

# %%
# Print out a nice report
print("\nData Quality Report")
print("Total records: {}".format(len(credit_card_default.index)))
data_quality_report
# Out:
# Data Quality Report
# Total records: 30000
#                    Data Type  Present Values  Missing Values  Unique Values  \
# DEFAULT                int32           30000               0              2
# age_bins            category           30000               0              6
# bill_avg             float64           30000               0          27370
# payment_avg          float64           30000               0          19180
# pay_ratio1           float64           30000               0          20209
# pay_ratio2           float64           30000               0          20042
# pay_ratio3           float64           30000               0          19411
# pay_ratio4           float64           30000               0          18580
# pay_ratio5           float64           30000               0          18025
# ratio_avg            float64           30000               0          24820
# util1                float64           30000               0          25565
# util2                float64           30000               0          25088
# util3                float64           30000               0          24738
# util4                float64           30000               0          24452
# util5                float64           30000               0          24075
# util6                float64           30000               0          24075
# util_avg             float64           30000               0          28402
# balance_growth_6mo   float64           30000               0          27137
# bill_max               int32           30000               0          23979
# payment_max            int32           30000               0          11670
# pay_max              float64           30000               0              9
# data.group             int64           30000               0              3
#
#                    Minimum Value  Maximum Value
# DEFAULT                        0              1
# age_bins                   21-30          71-80
# bill_avg           -56043.166667  877313.833333
# payment_avg                  0.0  627344.333333
# pay_ratio1                   0.0    4444.333333
# pay_ratio2                   0.0         5001.0
# pay_ratio3                   0.0    4444.333333
# pay_ratio4                   0.0     129.705128
# pay_ratio5                   0.0     690.655172
# ratio_avg                    0.0    2667.199955
# util1                  -0.619892         6.4553
# util2                   -1.39554         6.3805
# util3                    -1.0251      10.688575
# util4                    -1.3745        5.14685
# util5                  -0.876743         4.9355
# util6                  -0.876743         4.9355
# util_avg                -0.23259       5.537758
# balance_growth_6mo       -4.7004         1.7911
# bill_max                   -6029        1664089
# payment_max                    0        1684259
# pay_max                      0.0            8.0
# data.group                     1              3
